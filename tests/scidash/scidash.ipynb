# %% [markdown]
# ## Sciunit Testing Notebook for scidash

# %%
# %matplotlib inline
from IPython.display import display
import sys
if sys.path[0] != '/Users/rgerkin/Dropbox/dev/openworm/ChannelWorm/tests/scidash':
  sys.path.insert(0,'/Users/rgerkin/Dropbox/dev/openworm/ChannelWorm/tests/scidash')

# %%
import models, tests, suites

# %%
for test in tests.tests:
  score_array = test.judge(models.models, stop_on_error=True)
  display(score_array)

# %%
for suite in suites.suites:
  score_matrix = suite.judge(models.models, stop_on_error=True)
  display(score_matrix)
# Out:
# Executing test <i>EGL-19 IV</i> on model <i>EGL-19</i>...
# Score is <a style="color: rgb(230,78,52)">Fail</a>
#        EGL-19 IV
# EGL-19      Fail
# SLO-2    Unknown
# Executing test <i>SLO-2 IV</i> on model <i>SLO-2</i>...
# Score is <a style="color: rgb(230,78,52)">Fail</a>
#        SLO-2 IV
# EGL-19  Unknown
# SLO-2      Fail
